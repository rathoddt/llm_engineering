# %% [markdown]
# # End of week 1 solution
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!
#
# After week 2 you'll be able to add a User Interface to this tool, giving you a valuable application.

# %%
# imports

from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from openai import OpenAI
import ollama

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment

load_dotenv()
# openai = OpenAI()
OLLAMA_BASE_URL = "http://localhost:11434/v1"
ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
# prompts

system_prompt = "You are a helpful technical tutor who answers questions about python code, software engineering, data science and LLMs"
user_prompt = "Please give a detailed explanation to the following question: " + question

# %%
# messages

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
]

# %%
# # Get gpt-4o-mini to answer, with streaming

# stream = openai.chat.completions.create(model=MODEL_GPT, messages=messages,stream=True)
    
# response = ""
# display_handle = display(Markdown(""), display_id=True)
# for chunk in stream:
#     response += chunk.choices[0].delta.content or ''
#     response = response.replace("```","").replace("markdown", "")
#     update_display(Markdown(response), display_id=display_handle.display_id)

# %%
# Get gpt-4o-mini to answer, with streaming

stream = ollama.chat.completions.create(model=MODEL_LLAMA, messages=messages,stream=True)
    
response = ""
display_handle = display(Markdown(""), display_id=True)
for chunk in stream:
    response += chunk.choices[0].delta.content or ''
    response = response.replace("```","").replace("markdown", "")
    update_display(Markdown(response), display_id=display_handle.display_id)
# Out:
# **Code Explanation**
#
# The given code snippet is a generator expression, which is used to generate a sequence of values on-the-fly without storing them in memory. Let's break down the different components:
#
# - `yield from `{book.get("author") for book in books if book.get("author")}`: This is a yield-from expression, which is a variant of list comprehension with generator.
#
#   - `{book.get("author") for book in books if book.get("author")}`: This is an instance of a dict comprehension that produces all keys containing the desired key-value pair.
#
#     *   `for book` in `books`: Loops through each key-value pair from the dictionary called `"books"`.
#     *(note - if book.get("author") returns `None`, it won't be produced by the code as a required condition)
#
#     `(book.get("author")):` Produces just keys, not values.
#   - `yield from`: Sends one element from each of the sub-expressions returned by yields.
#
# Here's an equivalent for loop implementation to better illustrate how it works. This will output all the corresponding book authors if they contain a valid key-value pair:
#
# python
# def get_book_authors(books):
#     book_authors = []
#     for book in books:
#         author = next((value for key, value in book.items() if key == "author"), None)
#         if author is not None:
#             book_authors.append(author)
#
#     yield from book_authors
#
# # Equivalent
# def get_book_authors_simplified(books):
#     book_authors = (book.get("author")
#                    for book in books
#                    if book.get("author")
#                   )
#
#     # If you want to see the full book data, you can do this:
#     # print('Full Book Data: ')
#     # for index, author in enumerate(book_authors):
#     #     print(f"Author: {str(author)}, Full Book Data: {books[index]}")
#
# # Test Cases
# books1 = [
#    {"author": "John", "title": "Book 3"},
#    {"id": 0, "name": "Nora Holland", "book_info": "{\"key\": \"value\"}" },
#    {"id": 1, "key": {"name": "Jack"}},
#    {"author": None,"name":"Jack"}
#
# ]
# books = [
#     {"title": "Book 3" ,},
#      {"name": "Kare Smith",},
#
#     # ... more JSON-Like Dictionary
# ]
#
# get_book_authors_simplified(books)
#
#
#
# The original code can be used to iterate over the authors while iterating over `book`, as follows:
#
# python
# for author in get_book_authors(books):
#    print(f"The Book Author is : {str(author)}" )
#
#
#
# This approach is memory-optimized and better suited when working with large datasets.
#
# However, there are many nuances to this that may have been missed. Without more detail or context about what `"book"` is supposed to be (could "book" be an object rather than a dictionary? Or even any data type), then it might be necessary to make such examples much more elaborate and complicated.
#
#
#
# The next section provides code suggestions how you could do things on-the-fly.

# %%
# Get Llama 3.2 to answer

response = ollama.chat(model=MODEL_LLAMA, messages=messages)
reply = response['message']['content']
display(Markdown(reply))

# %% [markdown]
# # Congratulations!
#
# You could make it better by taking in the question using
# `my_question = input("Please enter your question:")`
#
# And then creating the prompts and making the calls interactively.
