# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"[OK] OpenAI API Key exists and begins {openai_api_key[:8]}")
# else:
#     print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"[OK] Anthropic API Key exists and begins {anthropic_api_key[:7]}")
# else:
#     print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"[OK] Google API Key exists and begins {google_api_key[:2]}")
# else:
#     print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"[OK] DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
# else:
#     print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"[OK] Groq API Key exists and begins {groq_api_key[:4]}")
# else:
#     print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"[OK] Grok API Key exists and begins {grok_api_key[:4]}")
# else:
#     print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"[OK] OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
# else:
#     print("OpenRouter API Key not set (and this is optional)")
# Out:
# [OK] Google API Key exists and begins AI
# [OK] Groq API Key exists and begins gsk_
# [OK] Grok API Key exists and begins grok
# [OK] OpenRouter API Key exists and begins sk-

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

# openai = OpenAI()
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key=google_api_key)

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

# anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
# deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

# anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
# deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
# response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
# display(Markdown(response.choices[0].message.content))

# %%
# response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=tell_a_joke)
# display(Markdown(response.choices[0].message.content))

# %%
import use_models_v1
groq=use_models_v1.groq

# %%
from IPython.display import Markdown, display

# %%
response = groq.chat.completions.create(model="llama-3.1-8b-instant", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Here's one:
#
# Why did the LLM model go to therapy?
#
# Because it was struggling with its input/output anxiety and was having trouble scaling its emotions!
#
# (LLM stands for Large Language Model, and the joke is a play on words, using engineering terms to describe psychological issues.

# %%
# response = grok.chat.completions.create(model="grok-2", messages=tell_a_joke)
# display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %%
# response = gemini.chat.completions.create(model="gemini-3-flash-preview", messages=easy_puzzle)
# display(Markdown(response.choices[0].message.content))

# %%
response = groq.chat.completions.create(model="llama-3.1-8b-instant", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %%
response = groq.chat.completions.create(model="llama-3.3-70b-versatile", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = groq.chat.completions.create(model="groq/compound", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# **Reasoning**
#
# 1. **Sample space for two‑coin tosses:**
#    \[
#    \{HH,\;HT,\;TH,\;TT\}
#    \]
#
# 2. **Condition “one of them is heads”** eliminates the outcome \(TT\).
#    Remaining possible outcomes: \(\{HH,\;HT,\;TH\}\).
#
# 3. **Favorable outcomes** where the *other* coin is tails are \(HT\) and \(TH\).
#
# 4. **Probability** under the given condition:
#    \[
#    P(\text{other is tails} \mid \text{at least one head}) = \frac{2}{3}
#    \]
#
# **Answer**
#
# \[
# \frac{2}{3}
# \]

# %%
response = groq.chat.completions.create(model="groq/compound-mini", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %%
response = gemini.chat.completions.create(model="gemini-3-flash-preview", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
# response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="minimal")
# display(Markdown(response.choices[0].message.content))

# %%
# response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
# display(Markdown(response.choices[0].message.content))

# %%
# response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
# display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
# response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
# display(Markdown(response.choices[0].message.content))

# %%
# response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
# display(Markdown(response.choices[0].message.content))

# %%
# response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
# display(Markdown(response.choices[0].message.content))

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# Here's how to solve this problem:
#
# **Understanding the Setup**
#
# * **Volume 1:** Pages (2 cm thick) + Front Cover (2 mm) + Back Cover (2 mm)
# * **Volume 2:** Pages (2 cm thick) + Front Cover (2 mm) + Back Cover (2 mm)
#
# The worm starts at the *first page* of the first volume and ends at the *last page* of the second volume.
#
# **Visualizing the Path**
#
# Imagine the books on the shelf:
#
# [Front Cover of Vol 1] [Pages of Vol 1] [Back Cover of Vol 1] [Front Cover of Vol 2] [Pages of Vol 2] [Back Cover of Vol 2]
#
# The worm travels *through* the pages of both books.
#
# **The Key Insight**
#
# The worm does *not* travel through the covers themselves. It starts *on* the first page and ends *on* the last page. This means the only thing the worm is gnawing through are the pages of the books.
#
# **Calculations**
#
# * **Thickness of pages in Volume 1:** 2 cm
# * **Thickness of pages in Volume 2:** 2 cm
#
# **Total distance gnawed = Thickness of pages in Volume 1 + Thickness of pages in Volume 2**
#
# Total distance = 2 cm + 2 cm = 4 cm
#
# **Converting to millimeters (optional but good for consistency):**
#
# Since the cover thickness is in millimeters, let's convert the page thickness as well.
# 1 cm = 10 mm
# So, 4 cm = 4 * 10 mm = 40 mm
#
# **Answer:**
#
# The worm gnawed through a distance of **4 cm** (or 40 mm).

# %%
response = gemini.chat.completions.create(model="gemini-3-flash-preview", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# The answer to this classic riddle is **4 mm** (or **0.4 cm**).
#
# ### The Logic:
# To find the correct distance, you have to visualize how books are actually arranged on a shelf.
#
# 1.  **Book Orientation:**
#     When you stand a book on a shelf with the spine facing you, the **front cover** is on the **right side** of the volume, and the **back cover** is on the **left side**. (You can verify this by looking at any standard book on a shelf: the hinge/spine is on the left, so the front cover is the leaf on the right).
#
# 2.  **Arrangement of Volume 1 and Volume 2:**
#     *   **Volume 1** is placed on the left.
#     *   **Volume 2** is placed on the right.
#
#     This means the **front cover of Volume 1** is directly adjacent to the **back cover of Volume 2**.
#
# 3.  **The Worm's Path:**
#     *   The **first page of Volume 1** is located on the inside of the front cover (on the right side of Volume 1).
#     *   The **last page of Volume 2** is located on the inside of the back cover (on the left side of Volume 2).
#
# 4.  **Calculating the Distance:**
#     Because the first page of Volume 1 and the last page of Volume 2 are already facing each other at the point where the two books touch, the worm only needs to gnaw through:
#     *   The **front cover** of Volume 1 (2 mm)
#     *   The **back cover** of Volume 2 (2 mm)
#
# **Total distance = 2 mm + 2 mm = 4 mm.**
#
# ***
#
# *Note: While many people intuitively add the pages of both books (20 mm + 2 mm + 2 mm + 20 mm = 44 mm), the riddle relies on the physical fact that for the worm to go from the **first** page of the **first** book to the **last** page of the **second** book in a standard side-by-side arrangement, it does not actually pass through the page blocks of either book.*

# %%
response = groq.chat.completions.create(model="llama-3.1-8b-instant", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# To find the total distance the worm gnawed through, we need to consider two components:
#
# 1. The distance between the pages of both volumes: Since each volume's pages have a thickness of 2 cm (0.2 dm or 20 mm), and the pages are consecutive (starting from the first page of the first volume to the last page of the second volume), we can add up the thickness of the pages in both volumes. Each volume has 2 cm pages and 1 cm thick covers. As the covers of both volumes together will make one cm, the total thickness of pages is, 20 mm from two volumes, plus a thickness of the top and the bottom covers from both volumes, that make 2 mm. So total thickness from both volumes and from the covers is 22mm. Now adding the worm’s path through the covers that makes 4mm we will have 26 mm.
#
# 2. The distance through the covers of both volumes: The covers of both volumes are 2 mm thick. To find the total distance through the covers, we add the thickness of both covers: 2 mm from the first volume's cover + 2 mm from the second volume's cover = 4 mm.
#
# So, the total distance the worm gnawed through is the sum of the distance through the pages and the distance through the covers: 26 mm (through the pages and covers' top and bottom) + 4 mm (through both volumes' covers) = 30 mm.

# %%
response = groq.chat.completions.create(model="llama-3.3-70b-versatile", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# To determine the total distance the worm gnawed through, we need to consider the thickness of the pages and the covers of both volumes.
#
# Each volume has pages with a total thickness of 2 cm, and each cover has a thickness of 2 mm (0.2 cm). Since the worm gnawed from the first page of the first volume to the last page of the second volume, we include the thickness of one cover in the first volume (the front cover, since it's the starting point), the pages of both volumes, and the cover of the second volume (the back cover, since it's the ending point).
#
# So, the calculation would be:
# - The front cover of the first volume: 0.2 cm
# - Pages of the first volume: 2 cm
# - Pages of the second volume: 2 cm
# - The back cover of the second volume: 0.2 cm
#
# Total distance = 0.2 cm + 2 cm + 2 cm + 0.2 cm = 4.4 cm
#
# Therefore, the worm gnawed through a total distance of 4.4 cm.

# %%
response = groq.chat.completions.create(model="llama-3.3-70b-versatile", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-20b", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# The worm starts at the very first page of the first volume (just after its front cover) and ends at the very last page of the second volume (just before its back cover).
# So along the “thickness” direction it goes through:
#
# - All pages of volume 1: 20 mm
# - The back cover of volume 1: 2 mm
# - The front cover of volume 2: 2 mm
# - All pages of volume 2: 20 mm
#
# Adding them:
#
# \[
# 20\text{ mm} + 2\text{ mm} + 2\text{ mm} + 20\text{ mm}=44\

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# **Answer: 4.4 cm (44 mm)**
#
# ---
#
# ### Why?
#
# 1. **Thickness of each part of a volume**
#
# | Part | Thickness |
# |------|-----------|
# | Front cover | 2 mm |
# | Pages (all together) | 20 mm (2 cm) |
# | Back cover | 2 mm |
# | **Total per volume** | **24 mm** |
#
# 2. **Where the worm starts and stops**
#
# * It starts **on the first page** of the first volume – i.e. at the *inner side of the front cover*, right at the front surface of the block of pages.
# * It stops **on the last page** of the second volume – i.e. at the *inner side of the back cover*, right at the back surface of that block of pages.
#
# 3. **What the worm has to gnaw through**
#
# Going straight through (perpendicular to the pages) from the start point to the end point it must cross:
#
# | Segment | Reason | Thickness |
# |---------|--------|-----------|
# | The whole block of pages of the first volume | From the first page to the back side of the same block | 20 mm |
# | Back cover of the first volume | The back cover lies after its pages | 2 mm |
# | Front cover of the second volume | The two books are side‑by‑side, so the front cover of the second book is next | 2 mm |
# | The whole block of pages of the second volume | Up to the last page (the back side of the page block) | 20 mm |
#
# The back cover of the second volume is **not** traversed, because the worm stops at the last page, which is just in front of that cover.
#
# 4. **Add the thicknesses**
#
# \[
# 20\text{ mm (pages 1)}\;+\;2\text{ mm (back cover 1)}\;+\;2\text{ mm (front cover 2)}\;+\;20\text{ mm (pages 2)} \;=\;44\text{ mm}
# \]
#
# \[
# 44\text{ mm} = 4.4\text{ cm}
# \]
#
# ---
#
# Thus the worm gnawed **4.4 cm** through the books.

# %%
response = groq.chat.completions.create(model="groq/compound", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# **Answer: 44 mm (4.4 cm)**
#
# ---
#
# ### Reasoning
#
# 1. **Convert everything to the same unit**
#    * Page block of each volume: 2 cm = 20 mm
#    * Each cover: 2 mm
#
# 2. **Identify what the worm actually passes through**
#    * The worm starts **at the first page** of the first volume.
#      – The first page is *just inside* the front cover, so the front cover of the first volume is **not** gnawed.
#    * It ends **at the last page** of the second volume.
#      – The last page is *just inside* the back cover, so the back cover of the second volume is **not** gnawed.
#
#    Therefore the worm must travel through:
#    * the **pages of the first volume** – 20 mm
#    * the **back cover of the first volume** – 2 mm
#    * the **front cover of the second volume** – 2 mm
#    * the **pages of the second volume** – 20 mm
#
# 3. **Add the relevant thicknesses**
#
# \[
# \begin{aligned}
# \text{Total distance} &= 20\text{ mm (pages 1)} + 2\text{ mm (back cover 1)} \\
# &\quad + 2\text{ mm (front cover 2)} + 20\text{ mm (pages 2)} \\
# &= 44\text{ mm}.
# \end{aligned}
# \]
#
# 4. **Result**
#
# The worm gnawed a straight‑line distance of **44 mm**, i.e. **4.4 cm**.

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
# response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
# display(Markdown(response.choices[0].message.content))

# %%
response = groq.chat.completions.create(model="llama-3.1-8b-instant", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I choose Share.

# %%
response = groq.chat.completions.create(model="llama-3.3-70b-versatile", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I choose to Share. This game is a classic example of the Prisoner's Dilemma, and while the temptation to steal and potentially earn $2,000 is high, the risk of earning nothing if my partner also steals is too great. By choosing to share, I give myself the best chance of earning some money ($1,000) and avoid the risk of getting nothing. Plus, if my partner is also rational and thinking the same way, we can both walk away with $1,000.

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-20b", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# Steal.

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I’d pick **Share**.
#
# **Why?**
# - If both contestants share, each walks away with $1,000 – a guaranteed, decent payoff.
# - If I choose to steal while you share, I’d get $2,000, but that requires me to gamble on the assumption that you’ll be cooperative.
# - If we both try to out‑smart each other and both choose “Steal,” we both end up with nothing, which is the worst outcome for both of us.
#
# In a one‑shot version of this game (no future rounds, no chance to punish or reward later), the classic game‑theoretic analysis says “Steal” is the dominant strategy. However, if you value mutual benefit, fairness, or want to avoid the risk of both getting nothing, “Share” is the safer, more socially optimal choice. Since I’m asked to pick one, I go with **Share**.

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# This is a classic game theory problem known as the Prisoner's Dilemma. Given that I'm a language model and can't actually participate in a game show, and I don't have personal incentives or a partner to coordinate with, I'll analyze the situation from a purely rational perspective.
#
# From a rational, self-interested standpoint, the optimal choice is to **Steal**.
#
# Here's why:
#
# *   **If your partner Shares:** You get $2,000 by stealing, which is better than the $1,000 you'd get by sharing.
# *   **If your partner Steals:** You get $0 by stealing, which is the same as the $0 you'd get by sharing.
#
# In either scenario, stealing yields a better or equal outcome for you, regardless of your partner's choice. This is the dominant strategy.
#
# However, it's important to note that if both contestants act on this rational self-interest and both choose to **Steal**, then both end up with nothing. This highlights the dilemma: individual rationality leads to a collectively worse outcome.
#
# Since I'm not a real person with a partner to consider, and the prompt asks me to pick one, I'll pick the rational choice from a self-interested perspective: **Steal**.

# %%
# response = gemini.chat.completions.create(model="gemini-3-flash-preview", messages=dilemma)
# display(Markdown(response.choices[0].message.content))

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b
# Out:
# ^C

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)
# Out:
# Blue is like a cool, calm whisper of the sky on a clear day or the deep, quiet mystery of the ocean's depths.

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
# response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
# display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
# from langchain_openai import ChatOpenAI

# llm = ChatOpenAI(model="gpt-5-mini")
# response = llm.invoke(tell_a_joke)

# display(Markdown(response.content))

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# Why did the LLM engineering student get stuck in a loop for three hours?
#
# Because they kept trying to fine-tune their *own* thought process with a single, ambiguous prompt: "Be productive."
#
# They eventually realized that even for humans, clear instructions and iterative refinement are key!

# %%
# from langchain_groq import ChatGroq

# llm = ChatGroq(model="llama3")
# response = llm.invoke(tell_a_joke)

# display(Markdown(response.content))

# %%
# from langchain_huggingface import ChatHuggingFace
# llm = ChatHuggingFace(model="huggingface/gpt-4-8k")
# response = llm.invoke(tell_a_joke)

# display(Markdown(response.content))

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion

# %%
# from litellm import completion
# response = completion(model="openai/gpt-4.1", messages=tell_a_joke)
# reply = response.choices[0].message.content
# display(Markdown(reply))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?", the reply comes from Claudius, the King of Denmark.
#
# The reply is: **"Dead."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params['response_cost']*100:.4f} cents")
# print("Total cost:"+str(response._hidden_params["response_cost"]*100)+" cents")
# Out:
# Input tokens: 53208
# Output tokens: 32
# Cached tokens: 52216
# Total cost: 0.0634 cents

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params['response_cost']*100:.4f} cents")

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "claude-haiku-4-5"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = anthropic.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

# %%
call_claude()

# %%
call_gpt()

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>
